# %% [markdown]
# Roda 015

# %%
##### Computação cietífica
import numpy as np
##### Manipulação e análise
import pandas as pd
##### Análise exploratória visual
import matplotlib.pyplot as plt
import seaborn as sns

# %%
result_final_g=pd.DataFrame()
for agg in [0,1]:
    for t in range(3):
        # %run '~/comex/code/015.ipynb'
        result_final['agg']=agg
        result_final['t']=t
        result_final_g=pd.concat([result_final_g, result_final])
# Out:
# Stored 'tpr_g_t' (DataFrame)
# Stored 'result_mes' (DataFrame)
# Stored 'd_pred' (DataFrame)
# Stored 'tpr_g_t' (DataFrame)
# Stored 'result_mes' (DataFrame)
# Stored 'd_pred' (DataFrame)
# Stored 'tpr_g_t' (DataFrame)
# Stored 'result_mes' (DataFrame)
# Stored 'd_pred' (DataFrame)
# Stored 'tpr_g_t' (DataFrame)
# Stored 'result_mes' (DataFrame)
# Stored 'd_pred' (DataFrame)
# Stored 'tpr_g_t' (DataFrame)
# Stored 'result_mes' (DataFrame)
# Stored 'd_pred' (DataFrame)
# Stored 'tpr_g_t' (DataFrame)
# Stored 'result_mes' (DataFrame)
# Stored 'd_pred' (DataFrame)

# %%
round(result_final_g.groupby(by=['NCM','grupo_mes','agg'])[['conf_oc','conf_KT']].mean(),1)
# Out:
#                           conf_oc  conf_KT
# NCM        grupo_mes agg
# 31021010-0 1         0        0.6      0.1
#                      1        1.0      0.1
#            2         0        0.9      0.2
#                      1        1.0      0.1
#            3         0        0.8      0.2
#                      1        1.0      0.4
# 31022100-0 1         0        0.4      0.1
#                      1        0.9      0.1
#            2         0        0.6      0.5
#                      1        1.0      0.0
#            3         0        0.8      0.6
#                      1        1.0      0.2
# 31042090-0 1         0        1.0      0.4
#                      1        1.0      0.3
#            2         0        1.0      0.3
#                      1        1.0      0.6
#            3         0        0.9      0.5
#                      1        1.0      0.6
# 31054000-0 1         0        0.8      0.1
#                      1        1.0      0.1
# ...
