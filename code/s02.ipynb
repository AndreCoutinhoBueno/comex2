# %% [markdown]
# ### <p style="text-align:center"> Análise Preditiva das Importações de Fertilizantes através dos Portos de Salvador e de Aratu-Candeias no Estado da Bahia</p>

# %% [markdown]
# > ### Sobre a Previsão:
# > Calculada com base nos dados divulgados pelo [Comex Stat]([http://comexstat.mdic.gov.br/pt/sobre), com uso do [scikit-learn](https://scikit-learn.org/stable/#), uma biblioteca de aprendizado de máquina de código aberto para a linguagem de programação [python](https://www.python.org/), uma linguagem de programação que permite trablhos rápidos e com intergração mais efeitva.
# >
# > A integra do processamento dos dados e geração de relatórios é reportada no Anexo I.

# %%
# %run '~/comex/code/Média Móvel Projetada.ipynb'

# %% [markdown]
# > A Média Móvel é a média dos últimos 12 meses.
# >
# > O eixo vertical do gráfico tem o valor multiplicado por 10 elevado a 7 potência (10 milhões de kg, ou 10 mil toneladas), como indicado no canto esquerdo superior do conjunto de gráficos.
